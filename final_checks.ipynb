# %%
import pandas as pd

# %%
pd.read_csv('/Users/luismoreira/Desktop/Final_project/Databases/table.csv')
# Out:
#       Unnamed: 0  index long_position_solar lat_position_solar  value_phov  \
# 0              0     40    (-9.604, -9.512]   (39.022, 39.075]   1555.2340
# 1              1    133    (-9.512, -9.423]     (38.646, 38.7]   1650.0613
# 2              2    141    (-9.512, -9.423]   (39.075, 39.129]   1545.9958
# 3              3    142    (-9.512, -9.423]   (39.129, 39.183]   1544.7921
# 4              4    232    (-9.423, -9.335]   (38.592, 38.646]   1666.3787
# ...          ...    ...                 ...                ...         ...
# 1370        2000   3367    (-6.685, -6.597]   (40.471, 40.524]   1593.7318
# 1371        2001   3368    (-6.685, -6.597]   (40.524, 40.578]   1591.1102
# 1372        2002   3369    (-6.685, -6.597]   (40.578, 40.632]   1593.5859
# 1373        2003   3370    (-6.685, -6.597]   (40.632, 40.685]   1592.8030
# 1374        2004   3373    (-6.685, -6.597]   (40.793, 40.846]   1591.0290
#
# ...

# %%
pd.read_csv('/Users/luismoreira/Desktop/Final_project/Databases/additional_features.csv')
# Out:
#          Unnamed: 0    long     lat      DIF       DNI       GHI       GTI
# 0                 0 -8.2050  42.235  578.191  1482.185  1453.330  1688.186
# 1                 1 -8.2025  42.235  582.939  1490.585  1459.174  1688.916
# 2                 2 -8.2000  42.235  584.765  1487.298  1459.539  1687.455
# 3                 3 -8.1975  42.235  584.035  1469.766  1454.791  1684.898
# 4                 4 -8.1950  42.235  574.904  1397.446  1427.397  1660.426
# ...             ...     ...     ...      ...       ...       ...       ...
# 1812128     1812128 -7.8850  36.875  585.861  2146.940  1887.977  2148.035
# 1812129     1812129 -7.8825  36.875  585.861  2146.574  1887.612  2148.035
# 1812130     1812130 -7.8800  36.875  585.861  2146.574  1887.612  2148.035
# 1812131     1812131 -7.8775  36.875  586.226  2146.209  1887.612  2148.035
# 1812132     1812132 -7.8750  36.875  586.226  2146.209  1887.612  2147.670
#
# [1812133 rows x 7 columns]

# %%
pd.read_csv('/Users/luismoreira/Desktop/Final_project/final_project/map_data.csv')
# Out:
#       Unnamed: 0  level_0  index       Phov   Elevation         long_bins  \
# 0              0        5    233  1649.0002  155.476274  (-9.496, -9.404]
# 1              1       12    332  1654.1453   83.547421  (-9.404, -9.312]
# 2              2       13    333  1634.1395  186.357420  (-9.404, -9.312]
# 3              3       14    334  1634.9681  139.481740  (-9.404, -9.312]
# 4              4       15    335  1611.8870  122.346542  (-9.404, -9.312]
# ...          ...      ...    ...        ...         ...               ...
# 1308        1308     1370   3367  1593.7318  550.602953  (-6.647, -6.556]
# 1309        1309     1371   3368  1591.1102  553.193473  (-6.647, -6.556]
# 1310        1310     1372   3369  1593.5859  615.346908  (-6.647, -6.556]
# 1311        1311     1373   3370  1592.8030  664.804973  (-6.647, -6.556]
# 1312        1312     1374   3373  1591.0290  811.846931  (-6.647, -6.556]
#
#               lat_bins  Inclination  lat_leftend  lat_rightend  long_leftend  \
# ...

# %%
pd.read_csv('/Users/luismoreira/Desktop/Final_project/final_project/topo.csv')
# Out:
#          Unnamed: 0   row   col  value         x          y
# 0                 0     0     0  -4726 -9.888000  43.999000
# 1                 1     0     1  -4717 -9.885639  43.999000
# 2                 2     0     2  -4708 -9.883279  43.999000
# 3                 3     0     3  -4699 -9.880918  43.999000
# 4                 4     0     4  -4690 -9.878557  43.999000
# ...             ...   ...   ...    ...       ...        ...
# 5580031     5580031  3387  1642   -186 -6.011803  36.002361
# 5580032     5580032  3387  1643   -187 -6.009443  36.002361
# 5580033     5580033  3387  1644   -189 -6.007082  36.002361
# 5580034     5580034  3387  1645   -191 -6.004721  36.002361
# 5580035     5580035  3387  1646   -194 -6.002361  36.002361
#
# [5580036 rows x 6 columns]
